# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#data from: https://www.jpl.nasa.gov/edu/teach/activity/graphing-global-temperature-trends/
# !wget -O globalTemp.csv https://www.dropbox.com/s/w5n763mnroln66v/globalTemp.csv?dl=0
# Out:
# --2022-01-18 11:55:24--  https://www.dropbox.com/s/w5n763mnroln66v/globalTemp.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/w5n763mnroln66v/globalTemp.csv [following]
# --2022-01-18 11:55:25--  https://www.dropbox.com/s/raw/w5n763mnroln66v/globalTemp.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc63502f009637d8e41659dda8fe.dl-eu.dropboxusercontent.com/cd/0/inline/BeDgSAWlKZ_ZMci95dlQIAncv4GgPYt-9k3_xJziv9O60jvsljz0-KbJuTm4HPFq6GYLuGVDkQ_UisL5NFavm4fsdKec3KVHXirv0yQnlYDS54GFW6RkyKjx3ABlbsQXdh7yaELOs_4Ov2bLCT30Od8M/file# [following]
# --2022-01-18 11:55:25--  https://uc63502f009637d8e41659dda8fe.dl-eu.dropboxusercontent.com/cd/0/inline/BeDgSAWlKZ_ZMci95dlQIAncv4GgPYt-9k3_xJziv9O60jvsljz0-KbJuTm4HPFq6GYLuGVDkQ_UisL5NFavm4fsdKec3KVHXirv0yQnlYDS54GFW6RkyKjx3ABlbsQXdh7yaELOs_4Ov2bLCT30Od8M/file
# Resolving uc63502f009637d8e41659dda8fe.dl-eu.dropboxusercontent.com (uc63502f009637d8e41659dda8fe.dl-eu.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc63502f009637d8e41659dda8fe.dl-eu.dropboxusercontent.com (uc63502f009637d8e41659dda8fe.dl-eu.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2950 (2.9K) [text/plain]
# Saving to: ‘globalTemp.csv’
#
# globalTemp.csv      100%[===================>]   2.88K  --.-KB/s    in 0s
#
# 2022-01-18 11:55:25 (612 MB/s) - ‘globalTemp.csv’ saved [2950/2950]

# %%
df=pd.read_csv('globalTemp.csv')

# %%
x = df['Year'].to_numpy()
y = df['Actual Temp'].to_numpy()
plt.plot(x,y)

# %%
##The change is smooth
Num=5
basis=np.arange(Num)
x=x[:,np.newaxis]
basis=basis[np.newaxis,:]
A=x**basis
print(A.shape)
y=y[:,np.newaxis]
w=np.linalg.inv(A.T@A)@(A.T@y)
yhat=A@w
plt.plot(x,y,x,yhat)
# Out:
# (31, 5)
# [<matplotlib.lines.Line2D at 0x7fa87140f410>,
#  <matplotlib.lines.Line2D at 0x7fa87140f650>]

# %%
df=df[(df['Year']>1943) & (df['Year']<1975)]
x = df['Year'].to_numpy()
y = df['Actual Temp'].to_numpy()
plt.plot(x,y)

# %%
##The change is smooth
Num=5
basis=np.arange(Num)
x=x[:,np.newaxis]
basis=basis[np.newaxis,:]
A=x**basis
print(A.shape)
y=y[:,np.newaxis]
w=np.linalg.inv(A.T@A)@(A.T@y)
yhat=A@w
plt.plot(x,y,x,yhat)
# Out:
# (31, 5)
# [<matplotlib.lines.Line2D at 0x7fa87136d310>,
#  <matplotlib.lines.Line2D at 0x7fa87136d550>]
